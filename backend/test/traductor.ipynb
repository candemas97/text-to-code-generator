# %%
import transformers

# %%
def traductor(pregunta: str) -> str:
    translator = transformers.pipeline("translation_es_to_en", model="Helsinki-NLP/opus-mt-es-en")
    english_quesion = translator(pregunta, clean_up_tokenization_spaces=True, truncation=True)
    return english_quesion[0]["translation_text"]

# %%
traductor("Funcion que divida por numeros pares")
# Out:
# WARNING:tensorflow:From c:\Users\sejo_\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\sejo_\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.logging.TaskLevelStatusMessage is deprecated. Please use tf.compat.v1.logging.TaskLevelStatusMessage instead.
#
# WARNING:tensorflow:From c:\Users\sejo_\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.control_flow_v2_enabled is deprecated. Please use tf.compat.v1.control_flow_v2_enabled instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\sejo_\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\utils\import_utils.py:1184, in _LazyModule._get_module(self, module_name)
#    1183 try:
# -> 1184     return importlib.import_module("." + module_name, self.__name__)
#    1185 except Exception as e:
#
# File c:\Users\sejo_\AppData\Local\Programs\Python\Python310\lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\sejo_\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\pipelines\__init__.py:71
#      70 from .question_answering import QuestionAnsweringArgumentHandler, QuestionAnsweringPipeline
# ---> 71 from .table_question_answering import TableQuestionAnsweringArgumentHandler, TableQuestionAnsweringPipeline
#      72 from .text2text_generation import SummarizationPipeline, Text2TextGenerationPipeline, TranslationPipeline
#
# File c:\Users\sejo_\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\pipelines\table_question_answering.py:26
#      25 import tensorflow as tf
# ---> 26 import tensorflow_probability as tfp
#      28 from ..models.auto.modeling_tf_auto import (
#      29     TF_MODEL_FOR_SEQ_TO_SEQ_CAUSAL_LM_MAPPING_NAMES,
#      30     TF_MODEL_FOR_TABLE_QUESTION_ANSWERING_MAPPING_NAMES,
#      31 )
#
# File c:\Users\sejo_\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_probability\__init__.py:20
#      17 # Contributors to the `python/` dir should not alter this file; instead update
#      18 # `python/__init__.py` as necessary.
# ---> 20 from tensorflow_probability import substrates
#      21 # from tensorflow_probability.google import staging  # DisableOnExport
#      22 # from tensorflow_probability.google import tfp_google  # DisableOnExport
#
# File c:\Users\sejo_\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_probability\substrates\__init__.py:17
#      15 """TensorFlow Probability alternative substrates."""
# ---> 17 from tensorflow_probability.python.internal import all_util
#      18 from tensorflow_probability.python.internal import lazy_loader  # pylint: disable=g-direct-tensorflow-import
#
# File c:\Users\sejo_\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_probability\python\__init__.py:138
#     137   for pkg_name in _maybe_nonlazy_load:
# --> 138     dir(globals()[pkg_name])  # Forces loading the package from its lazy loader.
#     141 all_util.remove_undocumented(__name__, _lazy_load + _maybe_nonlazy_load)
#
# File c:\Users\sejo_\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_probability\python\internal\lazy_loader.py:57, in LazyLoader.__dir__(self)
#      56 def __dir__(self):
# ---> 57   module = self._load()
#      58   return dir(module)
#
# File c:\Users\sejo_\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_probability\python\internal\lazy_loader.py:40, in LazyLoader._load(self)
#      39 # Import the target module and insert it into the parent's namespace
# ---> 40 module = importlib.import_module(self.__name__)
#      41 if self._parent_module_globals is not None:
#
# File c:\Users\sejo_\AppData\Local\Programs\Python\Python310\lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\sejo_\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_probability\python\experimental\__init__.py:31
#      30 from tensorflow_probability.python.experimental import auto_batching
# ---> 31 from tensorflow_probability.python.experimental import bayesopt
#      32 from tensorflow_probability.python.experimental import bijectors
#
# File c:\Users\sejo_\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_probability\python\experimental\bayesopt\__init__.py:17
#      15 """TensorFlow Probability experimental Bayesopt package."""
# ---> 17 from tensorflow_probability.python.experimental.bayesopt import acquisition
#      18 from tensorflow_probability.python.internal import all_util
#
# File c:\Users\sejo_\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_probability\python\experimental\bayesopt\acquisition\__init__.py:17
#      15 """Acquisition Functions."""
# ---> 17 from tensorflow_probability.python.experimental.bayesopt.acquisition.acquisition_function import AcquisitionFunction
#      18 from tensorflow_probability.python.experimental.bayesopt.acquisition.acquisition_function import MCMCReducer
#
# File c:\Users\sejo_\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_probability\python\experimental\bayesopt\acquisition\acquisition_function.py:22
#      21 from tensorflow_probability.python.internal import dtype_util
# ---> 22 from tensorflow_probability.python.internal import prefer_static as ps
#      23 from tensorflow_probability.python.internal import tensor_util
#
# File c:\Users\sejo_\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_probability\python\internal\prefer_static.py:361
#     360   return tf.ones(s, dtype or input.dtype, name)
# --> 361 ones_like = _copy_docstring(tf.ones_like, _ones_like)
#     364 def _rank(input, name=None):  # pylint: disable=redefined-builtin,unused-argument
#
# File c:\Users\sejo_\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_probability\python\internal\prefer_static.py:84, in _copy_docstring(original_fn, new_fn)
#      83 if original_spec != new_spec:
# ---> 84   raise ValueError(
#      85       'Arg specs do not match: original={}, new={}, fn={}'.format(
#      86           original_spec, new_spec, original_fn))
#      87 @decorator.decorator
#      88 def wrap(wrapped_fn, *args, **kwargs):
#
# ValueError: Arg specs do not match: original=FullArgSpec(args=['input', 'dtype', 'name', 'layout'], varargs=None, varkw=None, defaults=(None, None, None), kwonlyargs=[], kwonlydefaults=None, annotations={}), new=FullArgSpec(args=['input', 'dtype', 'name'], varargs=None, varkw=None, defaults=(None, None), kwonlyargs=[], kwonlydefaults=None, annotations={}), fn=<function ones_like_v2 at 0x00000292B6742950>
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# d:\SJ\MIA\PLN\Proyecto\text-to-code-generator\backend\test\traductor.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/SJ/MIA/PLN/Proyecto/text-to-code-generator/backend/test/traductor.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> traductor("Funcion que divida por numeros pares")
#
# d:\SJ\MIA\PLN\Proyecto\text-to-code-generator\backend\test\traductor.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/d%3A/SJ/MIA/PLN/Proyecto/text-to-code-generator/backend/test/traductor.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> def traductor(pregunta: str) -> str:
# ----> <a href='vscode-notebook-cell:/d%3A/SJ/MIA/PLN/Proyecto/text-to-code-generator/backend/test/traductor.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a>     translator = transformers.pipeline("translation_es_to_en", model="Helsinki-NLP/opus-mt-es-en")
#       <a href='vscode-notebook-cell:/d%3A/SJ/MIA/PLN/Proyecto/text-to-code-generator/backend/test/traductor.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a>     english_quesion = translator(pregunta, clean_up_tokenization_spaces=True, truncation=True)
#       <a href='vscode-notebook-cell:/d%3A/SJ/MIA/PLN/Proyecto/text-to-code-generator/backend/test/traductor.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a>     return english_quesion[0]["translation_text"]
#
# File c:\Users\sejo_\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\utils\import_utils.py:1174, in _LazyModule.__getattr__(self, name)
#    1172     value = self._get_module(name)
#    1173 elif name in self._class_to_module.keys():
# -> 1174     module = self._get_module(self._class_to_module[name])
#    1175     value = getattr(module, name)
#    1176 else:
#
# File c:\Users\sejo_\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\utils\import_utils.py:1186, in _LazyModule._get_module(self, module_name)
#    1184     return importlib.import_module("." + module_name, self.__name__)
#    1185 except Exception as e:
# -> 1186     raise RuntimeError(
#    1187         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1188         f" traceback):\n{e}"
#    1189     ) from e
#
# RuntimeError: Failed to import transformers.pipelines because of the following error (look up to see its traceback):
# Arg specs do not match: original=FullArgSpec(args=['input', 'dtype', 'name', 'layout'], varargs=None, varkw=None, defaults=(None, None, None), kwonlyargs=[], kwonlydefaults=None, annotations={}), new=FullArgSpec(args=['input', 'dtype', 'name'], varargs=None, varkw=None, defaults=(None, None), kwonlyargs=[], kwonlydefaults=None, annotations={}), fn=<function ones_like_v2 at 0x00000292B6742950>
